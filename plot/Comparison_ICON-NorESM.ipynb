# %% [markdown]
# # Model Comparison

# %%
# %load_ext autoreload
# %autoreload 2

import xarray as xr
import matplotlib.pyplot as plt 
import numpy as np
import pickle
import re


#Load my functions
from comparison_functions import *

# %%
ICON_NorESM_clim_path = '/work/aa0049/a271122/ICON_NorESM/'

# %% [markdown]
# ### ICON_NorESM

# %% [markdown]
# #### tas

# %%
tas_anomaly_list_84_14,tas_anomaly_list_15_39,tas_anomaly_list_40_69,tas_anomaly_list_70_99 = load_anomalies('tas',ICON_NorESM_clim_path)

# %%
tas_clim_list_84_14,tas_clim_list_15_39,tas_clim_list_40_69,tas_clim_list_70_99 = load_climatologies('tas',ICON_NorESM_clim_path)

# %%
tas_shape_list_84_14,tas_shape_list_15_39,tas_shape_list_40_69,tas_shape_list_70_99 = load_shapes('tas',ICON_NorESM_clim_path)

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(tas_anomaly_list_84_14,tas_anomaly_list_15_39,tas_anomaly_list_40_69,tas_anomaly_list_70_99,
                   tas_clim_list_84_14,tas_clim_list_15_39,tas_clim_list_40_69,tas_clim_list_70_99,'tas',
                   "Near-Surface Temperature Anomalies","Near-Surface Temperature Anomalies (°C)",
                   -15,35,ICON_NorESM_clim_path)

# %%
plot_box_and_clim(tas_anomaly_list_84_14,tas_anomaly_list_15_39,tas_anomaly_list_40_69,tas_anomaly_list_70_99,
                  tas_clim_list_84_14,tas_clim_list_15_39,tas_clim_list_40_69,tas_clim_list_70_99,
                  'tas',"Near-Surface Temperature Anomalies","Near-Surface Temperature Anomalies (K)",
                  -15,35,ICON_NorESM_clim_path,235,270)
# Out:
# Climatologies North Atlantic: 84: 258.16
#  15: 257.03
#  40: 261.45
#  70: 265.60
# Anomalies North Atlantic: 84: 11.50
#  15: 12.63
#  40: 7.77
#  70: 6.89
# Climatologies Central Arctic: 84: 238.53
#  15: 239.23
#  40: 243.86
#  70: 247.82
# Anomalies Central Arctic: 84: 15.77
#  15: 19.14
#  40: 15.71
#  70: 12.39
# Climatologies Beaufort Sea: 84: 240.07
#  15: 241.62
#  40: 245.88
#  70: 250.06
# Anomalies Beaufort Sea: 84: 9.67
#  15: 13.61
#  40: 10.12
#  70: 8.30

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(tas_shape_list_84_14,tas_shape_list_15_39,tas_shape_list_40_69,tas_shape_list_70_99,
                   tas_clim_list_84_14,tas_clim_list_15_39,tas_clim_list_40_69,tas_clim_list_70_99,
                   'tas',"Near-Surface Temperature","Near-Surface Temperature (K)",235,285,
                   ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# #### prw

# %%
# Integrated Water Vapor

# %%
# Anomalies

# %%
prw_anomaly_list_84_14,prw_anomaly_list_15_39,prw_anomaly_list_40_69,prw_anomaly_list_70_99 = load_anomalies('prw',ICON_NorESM_clim_path)

# %%
prw_shape_list_84_14,prw_shape_list_15_39,prw_shape_list_40_69,prw_shape_list_70_99 = load_shapes('prw',ICON_NorESM_clim_path)

# %%
prw_clim_list_84_14,prw_clim_list_15_39,prw_clim_list_40_69,prw_clim_list_70_99 = load_climatologies('prw',ICON_NorESM_clim_path)

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(prw_anomaly_list_84_14,prw_anomaly_list_15_39,prw_anomaly_list_40_69,prw_anomaly_list_70_99,
                   prw_clim_list_84_14,prw_clim_list_15_39,prw_clim_list_40_69,prw_clim_list_70_99,'prw',
                   "Integrated Water Vapor Anomalies",
                   "Integrated Water Vapor Anomalies (kg m-2)",-3.5,13,
                   ICON_NorESM_clim_path)

# %%
plot_box_and_clim(prw_anomaly_list_84_14,prw_anomaly_list_15_39,prw_anomaly_list_40_69,prw_anomaly_list_70_99,
                  prw_clim_list_84_14,prw_clim_list_15_39,prw_clim_list_40_69,prw_clim_list_70_99,
                  'prw',"Integrated Water Vapor Anomalies","Integrated Water Vapor Anomalies (kg m-2)",
                  -3.5,13,ICON_NorESM_clim_path,0,18)
# Out:
# Climatologies North Atlantic: 84: 4.02
#  15: 4.14
#  40: 4.77
#  70: 5.45
# Anomalies North Atlantic: 84: 4.99
#  15: 4.90
#  40: 5.61
#  70: 5.45
# Climatologies Central Arctic: 84: 1.88
#  15: 1.96
#  40: 2.39
#  70: 2.65
# Anomalies Central Arctic: 84: 4.17
#  15: 4.45
#  40: 5.25
#  70: 4.61
# Climatologies Beaufort Sea: 84: 2.27
#  15: 2.48
#  40: 2.82
#  70: 3.20
# Anomalies Beaufort Sea: 84: 2.77
#  15: 3.48
#  40: 3.28
#  70: 3.18

# %%
plot_box_years_new(prw_shape_list_84_14,prw_shape_list_15_39,prw_shape_list_40_69,prw_shape_list_70_99,
                   prw_clim_list_84_14,prw_clim_list_15_39,prw_clim_list_40_69,prw_clim_list_70_99,'prw',
                   "Integrated Water Vapor","Integrated Water Vapor (kg m-2)",
                   0,18,ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# #### rlds

# %%
# Anomalies

# %%
rlds_anomaly_list_84_14,rlds_anomaly_list_15_39,rlds_anomaly_list_40_69,rlds_anomaly_list_70_99 = load_anomalies('rlds',ICON_NorESM_clim_path)

# %%
rlds_clim_list_84_14,rlds_clim_list_15_39,rlds_clim_list_40_69,rlds_clim_list_70_99 = load_climatologies('rlds',ICON_NorESM_clim_path)

# %%
rlds_shape_list_84_14,rlds_shape_list_15_39,rlds_shape_list_40_69,rlds_shape_list_70_99 = load_shapes('rlds',ICON_NorESM_clim_path)

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(rlds_anomaly_list_84_14,rlds_anomaly_list_15_39,rlds_anomaly_list_40_69,rlds_anomaly_list_70_99,
                   rlds_clim_list_84_14,rlds_clim_list_15_39,rlds_clim_list_40_69,rlds_clim_list_70_99,'rlds',
                   'Longwave Down Radiation Anomalies',
                   "Longwave Downwelling Radiation Anomaly (W m-2)",
                   -65,160,ICON_NorESM_clim_path)

# %%
plot_box_and_clim(rlds_anomaly_list_84_14,rlds_anomaly_list_15_39,rlds_anomaly_list_40_69,rlds_anomaly_list_70_99,
                  rlds_clim_list_84_14,rlds_clim_list_15_39,rlds_clim_list_40_69,rlds_clim_list_70_99,
                  'rlds','Longwave Down Radiation Anomalies',"Longwave Downwelling Radiation Anomaly (W m-2)",
                  -65,160,ICON_NorESM_clim_path,145,325)
# Out:
# Climatologies North Atlantic: 84: 210.32
#  15: 208.09
#  40: 208.09
#  70: 236.93
# Anomalies North Atlantic: 84: 65.11
#  15: 69.23
#  40: 73.07
#  70: 53.10
# Climatologies Central Arctic: 84: 146.68
#  15: 148.99
#  40: 148.99
#  70: 169.85
# Anomalies Central Arctic: 84: 80.31
#  15: 88.00
#  40: 106.35
#  70: 78.67
# Climatologies Beaufort Sea: 84: 153.21
#  15: 158.28
#  40: 158.28
#  70: 178.99
# Anomalies Beaufort Sea: 84: 51.73
#  15: 72.71
#  40: 74.58
#  70: 60.16

# %%
plot_box_years_new(rlds_shape_list_84_14,rlds_shape_list_15_39,rlds_shape_list_40_69,rlds_shape_list_70_99,
                   rlds_clim_list_84_14,rlds_clim_list_15_39,rlds_clim_list_40_69,rlds_clim_list_70_99,'rlds',
                   'Longwave Down Radiation',"Longwave Downwelling Radiation (W m-2)",
                   140,340,ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# #### sfcWind

# %%
sfcWind_anomaly_list_84_14,sfcWind_anomaly_list_15_39,sfcWind_anomaly_list_40_69,sfcWind_anomaly_list_70_99 = load_anomalies('sfcWind',ICON_NorESM_clim_path)

# %%
sfcWind_shape_list_84_14,sfcWind_shape_list_15_39,sfcWind_shape_list_40_69,sfcWind_shape_list_70_99 = load_shapes('sfcWind',ICON_NorESM_clim_path)

# %%
sfcWind_clim_list_84_14,sfcWind_clim_list_15_39,sfcWind_clim_list_40_69,sfcWind_clim_list_70_99 = load_climatologies('sfcWind',ICON_NorESM_clim_path)

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(sfcWind_anomaly_list_84_14,sfcWind_anomaly_list_15_39,sfcWind_anomaly_list_40_69,sfcWind_anomaly_list_70_99,
                   sfcWind_clim_list_84_14,sfcWind_clim_list_15_39,sfcWind_clim_list_40_69,sfcWind_clim_list_70_99,'sfcWind',
                   'Wind Speed Anomalies',
                   "Near-Surface Wind Speed Anomaly (m s-1)",
                   -8,18,ICON_NorESM_clim_path,clim=False)

# %%
plot_box_and_clim(sfcWind_anomaly_list_84_14,sfcWind_anomaly_list_15_39,sfcWind_anomaly_list_40_69,sfcWind_anomaly_list_70_99,
                  sfcWind_clim_list_84_14,sfcWind_clim_list_15_39,sfcWind_clim_list_40_69,sfcWind_clim_list_70_99,
                  'sfcWind','Wind Speed Anomalies',"Near-Surface Wind Speed Anomaly (m s-1)",
                  -8,18,ICON_NorESM_clim_path,0,14)
# Out:
# Climatologies North Atlantic: 84: 7.62
#  15: 7.30
#  40: 7.46
#  70: 7.83
# Anomalies North Atlantic: 84: 2.98
#  15: 3.56
#  40: 2.92
#  70: 1.96
# Climatologies Central Arctic: 84: 5.11
#  15: 5.08
#  40: 5.10
#  70: 5.36
# Anomalies Central Arctic: 84: 5.53
#  15: 5.17
#  40: 4.29
#  70: 4.17
# Climatologies Beaufort Sea: 84: 5.00
#  15: 5.15
#  40: 5.29
#  70: 5.56
# Anomalies Beaufort Sea: 84: 4.67
#  15: 4.98
#  40: 6.03
#  70: 5.52

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(sfcWind_shape_list_84_14,sfcWind_shape_list_15_39,sfcWind_shape_list_40_69,sfcWind_shape_list_70_99,
                   sfcWind_clim_list_84_14,sfcWind_clim_list_15_39,sfcWind_clim_list_40_69,sfcWind_clim_list_70_99,'sfcWind',
                   'Wind Speed',
                   "Near-Surface Wind Speed (m s-1)",
                   0,22,ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# #### hfls

# %%
hfls_anomaly_list_84_14,hfls_anomaly_list_15_39,hfls_anomaly_list_40_69,hfls_anomaly_list_70_99 = load_anomalies('hfls',ICON_NorESM_clim_path)

# %%
hfls_shape_list_84_14,hfls_shape_list_15_39,hfls_shape_list_40_69,hfls_shape_list_70_99 = load_shapes('hfls',ICON_NorESM_clim_path)

# %%
hfls_clim_list_84_14,hfls_clim_list_15_39,hfls_clim_list_40_69,hfls_clim_list_70_99 = load_climatologies('hfls',ICON_NorESM_clim_path)

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(hfls_anomaly_list_84_14,hfls_anomaly_list_15_39,hfls_anomaly_list_40_69,hfls_anomaly_list_70_99,
                   hfls_clim_list_84_14,hfls_clim_list_15_39,hfls_clim_list_40_69,hfls_clim_list_70_99,
                   'hfls','Latent Heat Flux Anomalies',"Surface Upward Latent Heat Flux Anomaly (W m-2)",
                   -145,180,ICON_NorESM_clim_path,clim=False)

# %%
plot_box_and_clim(hfls_anomaly_list_84_14,hfls_anomaly_list_15_39,hfls_anomaly_list_40_69,hfls_anomaly_list_70_99,
                  hfls_clim_list_84_14,hfls_clim_list_15_39,hfls_clim_list_40_69,hfls_clim_list_70_99,
                  'hfls','Latent Heat Flux Anomalies',"Surface Upward Latent Heat Flux Anomaly(W m-2)",
                  -145,180,ICON_NorESM_clim_path,-2,60)
# Out:
# Climatologies North Atlantic: 84: 39.63
#  15: 29.74
#  40: 29.74
#  70: 46.19
# Anomalies North Atlantic: 84: -13.84
#  15: -12.40
#  40: -20.05
#  70: -23.11
# Climatologies Central Arctic: 84: -0.21
#  15: -0.34
#  40: -0.34
#  70: 0.16
# Anomalies Central Arctic: 84: -2.03
#  15: -0.80
#  40: -1.84
#  70: -0.41
# Climatologies Beaufort Sea: 84: -0.21
#  15: -0.08
#  40: -0.08
#  70: 2.45
# Anomalies Beaufort Sea: 84: -0.52
#  15: -0.34
#  40: 1.27
#  70: 1.49

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(hfls_shape_list_84_14,hfls_shape_list_15_39,hfls_shape_list_40_69,hfls_shape_list_70_99,
                   hfls_clim_list_84_14,hfls_clim_list_15_39,hfls_clim_list_40_69,hfls_clim_list_70_99,
                   'hfls','Latent Heat Flux',"Surface Upward Latent Heat Flux (W m-2)",
                   -50,210,ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# #### hfss

# %%
hfss_anomaly_list_84_14,hfss_anomaly_list_15_39,hfss_anomaly_list_40_69,hfss_anomaly_list_70_99 = load_anomalies('hfss',ICON_NorESM_clim_path)

# %%
hfss_shape_list_84_14,hfss_shape_list_15_39,hfss_shape_list_40_69,hfss_shape_list_70_99 = load_shapes('hfss',ICON_NorESM_clim_path)

# %%
hfss_clim_list_84_14,hfss_clim_list_15_39,hfss_clim_list_40_69,hfss_clim_list_70_99 = load_climatologies('hfss',ICON_NorESM_clim_path)

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(hfss_anomaly_list_84_14,hfss_anomaly_list_15_39,hfss_anomaly_list_40_69,hfss_anomaly_list_70_99,
                   hfss_clim_list_84_14,hfss_clim_list_15_39,hfss_clim_list_40_69,hfss_clim_list_70_99,'hfss',
                   'Sensible Heat Flux Anomalies',
                   "Surface Upward Sensible Heat Flux Anomaly (W m-2)",
                   -165,205,ICON_NorESM_clim_path,clim=False)

# %%
plot_box_and_clim(hfss_anomaly_list_84_14,hfss_anomaly_list_15_39,hfss_anomaly_list_40_69,hfss_anomaly_list_70_99,
                  hfss_clim_list_84_14,hfss_clim_list_15_39,hfss_clim_list_40_69,hfss_clim_list_70_99,
                  'hfss','Sensible Heat Flux Anomalies',"Surface Upward Sensible Heat Flux Anomaly(W m-2)",
                  -165,205,ICON_NorESM_clim_path,-20,60)
# Out:
# Climatologies North Atlantic: 84: 45.19
#  15: 31.80
#  40: 31.80
#  70: 40.73
# Anomalies North Atlantic: 84: -36.75
#  15: -37.50
#  40: -49.18
#  70: -42.17
# Climatologies Central Arctic: 84: -14.51
#  15: -13.91
#  40: -13.91
#  70: -10.73
# Anomalies Central Arctic: 84: -6.64
#  15: -4.76
#  40: -4.57
#  70: -3.71
# Climatologies Beaufort Sea: 84: -12.09
#  15: -10.98
#  40: -10.98
#  70: -4.58
# Anomalies Beaufort Sea: 84: -5.89
#  15: 0.31
#  40: 1.96
#  70: 1.75

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(hfss_shape_list_84_14,hfss_shape_list_15_39,hfss_shape_list_40_69,hfss_shape_list_70_99,
                   hfss_clim_list_84_14,hfss_clim_list_15_39,hfss_clim_list_40_69,hfss_clim_list_70_99,'hfss',
                   'Sensible Heat Flux',
                   "Surface Upward Sensible Heat Flux (W m-2)",
                   -90,205,ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# #### pr

# %%
pr_anomaly_list_84_14,pr_anomaly_list_15_39,pr_anomaly_list_40_69,pr_anomaly_list_70_99 = load_anomalies('pr',ICON_NorESM_clim_path)

# %%
pr_clim_list_84_14,pr_clim_list_15_39,pr_clim_list_40_69,pr_clim_list_70_99 = load_climatologies('pr',ICON_NorESM_clim_path)

# %%
pr_shapes_list_84_14,pr_shapes_list_15_39,pr_shapes_list_40_69,pr_shapes_list_70_99 = load_shapes('pr',ICON_NorESM_clim_path)

# %%
# Multiply each array by 3600
pr_anomaly_list_84_14 = [arr * 3600 for arr in pr_anomaly_list_84_14]
pr_anomaly_list_15_39 = [arr * 3600 for arr in pr_anomaly_list_15_39]
pr_anomaly_list_40_69 = [arr * 3600 for arr in pr_anomaly_list_40_69]
pr_anomaly_list_70_99 = [arr * 3600 for arr in pr_anomaly_list_70_99]


# Multiply each array by 3600
pr_shapes_list_84_14 = [arr * 3600 for arr in pr_shapes_list_84_14]
pr_shapes_list_15_39 = [arr * 3600 for arr in pr_shapes_list_15_39]
pr_shapes_list_40_69 = [arr * 3600 for arr in pr_shapes_list_40_69]
pr_shapes_list_70_99 = [arr * 3600 for arr in pr_shapes_list_70_99]

# %%
pr_clim_list_84_14[0].pr.mean(dim='time').mean(dim=('rlat','rlon')).values*3600
# Out:
# 0.07908334155217744

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(pr_anomaly_list_84_14,pr_anomaly_list_15_39,pr_anomaly_list_40_69,pr_anomaly_list_70_99,
                   pr_clim_list_84_14,pr_clim_list_15_39,pr_clim_list_40_69,pr_clim_list_70_99,'pr',
                   'Precipitation Anomalies',
                   "Precipitation Anomaly (mm h-1)",
                   -0.3,2.2,ICON_NorESM_clim_path)

# %%
plot_box_and_clim(pr_anomaly_list_84_14,pr_anomaly_list_15_39,pr_anomaly_list_40_69,pr_anomaly_list_70_99,
                  pr_clim_list_84_14,pr_clim_list_15_39,pr_clim_list_40_69,pr_clim_list_70_99,
                  'pr','Precipitation Anomalies',"Precipitation Anomaly (mm h-1)",
                  -0.3,2.2,ICON_NorESM_clim_path,0,0.6)
# Out:
# Climatologies North Atlantic:  84: 0.08
#  15: 0.07
#  40: 0.07
#  70: 0.09
# Anomalies North Atlantic: 84: 0.13
#  15: 0.17
#  40: 0.18
#  70: 0.17
# Climatologies Central Arctic:  84: 0.01
#  15: 0.01
#  40: 0.01
#  70: 0.02
# Anomalies Central Arctic: 84: 0.15
#  15: 0.10
#  40: 0.14
#  70: 0.16
# Climatologies Beaufort Sea:  84: 0.01
#  15: 0.02
#  40: 0.02
#  70: 0.02
# Anomalies Beaufort Sea: 84: 0.03
#  15: 0.06
#  40: 0.11
#  70: 0.10

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(pr_shapes_list_84_14,pr_shapes_list_15_39,pr_shapes_list_40_69,pr_shapes_list_70_99,
                   pr_clim_list_84_14,pr_clim_list_15_39,pr_clim_list_40_69,pr_clim_list_70_99,'pr',
                   'Precipitation',
                   "Precipitation (mm h-1)",
                   -0.02,2.8,ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# #### clwvi

# %%
clwvi_anomaly_list_84_14,clwvi_anomaly_list_15_39,clwvi_anomaly_list_40_69,clwvi_anomaly_list_70_99 = load_anomalies('clwvi',ICON_NorESM_clim_path)

# %%
clwvi_shape_list_84_14,clwvi_shape_list_15_39,clwvi_shape_list_40_69,clwvi_shape_list_70_99 = load_shapes('clwvi',ICON_NorESM_clim_path)

# %%
clwvi_clim_list_84_14,clwvi_clim_list_15_39,clwvi_clim_list_40_69,clwvi_clim_list_70_99 = load_climatologies('clwvi',ICON_NorESM_clim_path)

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(clwvi_anomaly_list_84_14,clwvi_anomaly_list_15_39,clwvi_anomaly_list_40_69,clwvi_anomaly_list_70_99,
                   clwvi_clim_list_84_14,clwvi_clim_list_15_39,clwvi_clim_list_40_69,clwvi_clim_list_70_99,'clwvi',
                   'Liquid Water Path Anomalies',
                   "Liquid Water Path Anomaly (kg m-2)",
                   -0.06,0.33,ICON_NorESM_clim_path)

# %%
plot_box_and_clim(clwvi_anomaly_list_84_14,clwvi_anomaly_list_15_39,clwvi_anomaly_list_40_69,clwvi_anomaly_list_70_99,
                  clwvi_clim_list_84_14,clwvi_clim_list_15_39,clwvi_clim_list_40_69,clwvi_clim_list_70_99,
                  'clwvi','Cloud Liquid Water Anomalies',"Total Column Cloud Liquid Water Anomaly (kg m-2)",
                  -0.06,0.33,ICON_NorESM_clim_path,-0.06,0.35)
# Out:
# Climatologies North Atlantic: 84: 0.03
#  15: 0.03
#  40: 0.03
#  70: 0.03
# Anomalies North Atlantic: 84: 0.04
#  15: 0.04
#  40: 0.06
#  70: 0.06
# Climatologies Central Arctic: 84: 0.01
#  15: 0.01
#  40: 0.01
#  70: 0.01
# Anomalies Central Arctic: 84: 0.04
#  15: 0.03
#  40: 0.05
#  70: 0.04
# Climatologies Beaufort Sea: 84: 0.01
#  15: 0.01
#  40: 0.01
#  70: 0.01
# Anomalies Beaufort Sea: 84: 0.01
#  15: 0.03
#  40: 0.03
#  70: 0.03

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(clwvi_shape_list_84_14,clwvi_shape_list_15_39,clwvi_shape_list_40_69,clwvi_shape_list_70_99,
                   clwvi_clim_list_84_14,clwvi_clim_list_15_39,clwvi_clim_list_40_69,clwvi_clim_list_70_99,'clwvi',
                   'Cloud Liquid Water',
                   "Total Column Cloud Liquid Water (kg m-2)",
                   -0.06,0.35,ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# #### clivi

# %%
clivi_anomaly_list_84_14,clivi_anomaly_list_15_39,clivi_anomaly_list_40_69,clivi_anomaly_list_70_99 = load_anomalies('clivi',ICON_NorESM_clim_path)

# %%
clivi_shape_list_84_14,clivi_shape_list_15_39,clivi_shape_list_40_69,clivi_shape_list_70_99 = load_shapes('clivi',ICON_NorESM_clim_path)

# %%
clivi_clim_list_84_14,clivi_clim_list_15_39,clivi_clim_list_40_69,clivi_clim_list_70_99 = load_climatologies('clivi',ICON_NorESM_clim_path)

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(clivi_anomaly_list_84_14,clivi_anomaly_list_15_39,clivi_anomaly_list_40_69,clivi_anomaly_list_70_99,
                   clivi_clim_list_84_14,clivi_clim_list_15_39,clivi_clim_list_40_69,clivi_clim_list_70_99,'clivi',
                   'Cloud Ice Water Anomalies',
                   "Total Column Cloud Ice Water Anomaly (kg m-2)",
                   -0.05,0.18,ICON_NorESM_clim_path)

# %%
plot_box_and_clim(clivi_anomaly_list_84_14,clivi_anomaly_list_15_39,clivi_anomaly_list_40_69,clivi_anomaly_list_70_99,
                  clivi_clim_list_84_14,clivi_clim_list_15_39,clivi_clim_list_40_69,clivi_clim_list_70_99,
                  'clivi','Cloud Ice Water Anomalies',"Total Column Cloud Ice Water Anomaly (kg m-2)",
                  -0.05,0.18,ICON_NorESM_clim_path,-0.06,0.35)
# Out:
# Climatologies North Atlantic: 84: 0.02
#  15: 0.02
#  40: 0.02
#  70: 0.02
# Anomalies North Atlantic: 84: 0.02
#  15: 0.02
#  40: 0.02
#  70: 0.02
# Climatologies Central Arctic: 84: 0.01
#  15: 0.01
#  40: 0.01
#  70: 0.01
# Anomalies Central Arctic: 84: 0.03
#  15: 0.02
#  40: 0.02
#  70: 0.03
# Climatologies Beaufort Sea: 84: 0.01
#  15: 0.01
#  40: 0.01
#  70: 0.01
# Anomalies Beaufort Sea: 84: 0.01
#  15: 0.01
#  40: 0.03
#  70: 0.02

# %%
#this is relative to a respective climatology (e.g. 1985-2014 temperature values - 1984-2014 climatology)
plot_box_years_new(clivi_shape_list_84_14,clivi_shape_list_15_39,clivi_shape_list_40_69,clivi_shape_list_70_99,
                   clivi_clim_list_84_14,clivi_clim_list_15_39,clivi_clim_list_40_69,clivi_clim_list_70_99,'clivi',
                   'Ice Water Path',
                   "Ice Water Path (kg m-2)",
                   -0.01,0.21,ICON_NorESM_clim_path,clim=True)

# %% [markdown]
# ### Test

# %%
clivi_anomaly_list_84_14,clivi_anomaly_list_15_39,clivi_anomaly_list_40_69,clivi_anomaly_list_70_99 = load_anomalies('clivi',ICON_NorESM_clim_path)

# %%
def load_climatologies(var,ICON_clim_path):
    '''Function to load previously computed anomaly lists for plotting development over centuries'''
    #Open shape_lists
    with open(f'{ICON_clim_path}shapelists/{var}_clim_list.pkl', 'rb') as f:
       clim_list_84_14 = pickle.load(f) 
    with open(f'{ICON_clim_path}ssp/shapelists/{var}_clim_list_15-39.pkl', 'rb') as f:
       clim_list_15_39 = pickle.load(f)
    with open(f'{ICON_clim_path}ssp/shapelists/{var}_clim_list_40-69.pkl', 'rb') as f:
       clim_list_40_69 = pickle.load(f)
    with open(f'{ICON_clim_path}ssp/shapelists/{var}_clim_list_70-99.pkl', 'rb') as f:
       clim_list_70_99 = pickle.load(f)


    return clim_list_84_14,clim_list_15_39,clim_list_40_69,clim_list_70_99

# %%
clivi_clim_list_84_14,clivi_clim_list_15_39,clivi_clim_list_40_69,clivi_clim_list_70_99 = load_climatologies('clivi',ICON_NorESM_clim_path)

# %%
fig, ax = plt.subplots(1,1)
value = clivi_clim_list_84_14[idx].clivi.mean(dim='time').mean(dim=('rlat','rlon')).values
ax.axhline(y=value)

# %%
titles = ['North Atlantic', 'Central Arctic', 'Beaufort Sea']

fig, axs = plt.subplots(1, 3, figsize=(8, 10), sharey=True)


#Here, we need to define a second axis that is only visible in the third box on the right side 
#second axis shows climatology as a line 

# Define colors for each dataset
colors = ["darkblue","darkred", "#D95F02"]
alpha_ = [1,0.8,0.6,0.4]

for idx, (title, ax) in enumerate(zip(titles, axs)):
    ax2 = ax.twinx()
    positions=[1, 2, 3, 4]
    ax2.hlines([clivi_clim_list_84_14[idx].clivi.mean(dim='time').mean(dim=('rlat','rlon')).values,clivi_clim_list_15_39[idx].clivi.mean(dim='time').mean(dim=('rlat','rlon')).values,clivi_clim_list_40_69[idx].clivi.mean(dim='time').mean(dim=('rlat','rlon')).values,clivi_clim_list_70_99[idx].clivi.mean(dim='time').mean(dim=('rlat','rlon')).values],
                [p - 0.3 for p in positions],  # xmin per box
                [p + 0.3 for p in positions],  # xmax per box
                colors='black', linewidth=2,linestyle='--')
    # Create boxplots
    bp = ax.boxplot(
        [clivi_anomaly_list_84_14[idx],clivi_anomaly_list_15_39[idx],clivi_anomaly_list_40_69[idx],clivi_anomaly_list_70_99[idx]],
        positions=[1, 2, 3, 4], 
        patch_artist=True,  # Allows setting box colors
        showmeans=True,
        meanprops=dict(marker='o', markerfacecolor='white', markeredgecolor='black', markersize=7),
        whis = (1, 99)
    )
    color = colors[idx]

    

    # Set colors for boxes, whiskers, caps, medians, and outliers
    for i, (box, alp) in enumerate(zip(bp['boxes'], alpha_)):
        box.set(facecolor=color, alpha=alp, edgecolor='black')

        # Whiskers and caps
        for whisker in bp['whiskers'][2 * i:2 * i + 2]:
            whisker.set(color=color, linewidth=1.2)
        for cap in bp['caps'][2 * i:2 * i + 2]:
            cap.set(color=color, linewidth=1.2)

        # Medians
        bp['medians'][i].set(color='black', linewidth=1.0)
        bp['medians'][i].set_clip_on(True)


        # Skip fliers since we're using whis='range'
        # Outlier points
        bp['fliers'][i].set(marker='o', markerfacecolor=color, markeredgecolor=color, alpha=alp, markersize=5)



    # Set axis labels and formatting
    ax.set_xticks([1, 2, 3, 4])
    ax.set_xticklabels(["", "", "", ""], rotation=90)

    ax.set_xticklabels(["1985-2014", "2015-2039", "2040-2069", "2070-2099"], rotation=90)
    ax.set_ylim([-0.05,0.18])
    ax.set_xlabel(title, labelpad=20, y=-0.25)

    #Set second axis values
    ax2.set_ylim([0.008,0.018])


    if idx == 0:
        ax.set_ylabel("Ice Water Path Anomaly (kg m-2)")
        ax2.yaxis.set_visible(False)  

    elif idx == 2: 
        ax2.set_ylabel("Climatological Mean (kg m-2)")  
    else:
        ax.yaxis.set_visible(False) 
        ax2.yaxis.set_visible(False)  

plt.subplots_adjust(wspace=0.05)
fig.suptitle('Ice Water Path Anomalies', fontweight='bold',y=0.92,fontsize=20)

plt.show()

# %% [markdown]
# ### Return clim values

# %%
with open("/work/aa0049/a271122/ICON_NorESM/shapelists/prw_clim_list.pkl", 'rb') as f:
       clim_IWV_his = pickle.load(f) 

with open("/work/aa0049/a271122/ICON_NorESM/ssp/shapelists/prw_clim_list_70-99.pkl", 'rb') as f:
       clim_IWV_ssp = pickle.load(f)

# %%
clim_IWV_his[1].prw.mean(dim='time').mean(dim=['rlat','rlon'])
# Out:
# <xarray.DataArray 'prw' ()>
# array(1.8772209, dtype=float32)

# %%
clim_IWV_ssp[1].prw.mean(dim='time').mean(dim=['rlat','rlon'])
# Out:
# <xarray.DataArray 'prw' ()>
# array(2.6495917, dtype=float32)

# %%
with open("/work/aa0049/a271122/ICON_NorESM/shapelists/tas_clim_list.pkl", 'rb') as f:
       clim_tas_his = pickle.load(f) 

with open("/work/aa0049/a271122/ICON_NorESM/ssp/shapelists/tas_clim_list_70-99.pkl", 'rb') as f:
       clim_tas_ssp = pickle.load(f)

# %%
clim_tas_his[1].tas.mean(dim='time').mean(dim=['rlat','rlon'])
# Out:
# <xarray.DataArray 'tas' ()>
# array(238.53128, dtype=float32)
# Coordinates:
#     height   float64 2.0

# %%
clim_tas_ssp[1].tas.mean(dim='time').mean(dim=['rlat','rlon'])
# Out:
# <xarray.DataArray 'tas' ()>
# array(247.82361, dtype=float32)
# Coordinates:
#     height   float64 2.0

# %%
diff_IWV = clim_IWV_ssp[1].prw.mean(dim='time').mean(dim=['rlat','rlon']).item() - clim_IWV_his[1].prw.mean(dim='time').mean(dim=['rlat','rlon']).item()
diff_IWV
# Out:
# 0.7723708152770996

# %%
diff_tas = clim_tas_ssp[1].tas.mean(dim='time').mean(dim=['rlat','rlon']).item() - clim_tas_his[1].tas.mean(dim='time').mean(dim=['rlat','rlon']).item()
diff_tas
# Out:
# 9.292327880859375
